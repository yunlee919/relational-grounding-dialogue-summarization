# %% [markdown]
# # Inspect Published Outputs
#
# This notebook is a lightweight entry point for browsing the released model outputs.
# It reads the committed CSV artifact and lets you inspect sample-level generations without rerunning models.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
path = ROOT / "outputs" / "direct" / "all_models" / "direct_all_models_100samples_seed42_results.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    model_label  sample_index      model_name  \
# 0  aya_expanse             0  aya-expanse:8b
# 1  aya_expanse             1  aya-expanse:8b
# 2  aya_expanse             2  aya-expanse:8b
# 3  aya_expanse             3  aya-expanse:8b
# 4  aya_expanse             4  aya-expanse:8b
#
#                                 generated_summary_zh  \
# 0  麦克斯问派顿是否知道哪里可以买到好衣服。派顿列出了几个网站，但表示通常会从两个或三个网站购买...
# 1  奥利、凯利、米奇和杰西卡在聊天，分享他们认为最可怕或最令人印象深刻的地方。凯利提到芬兰的一个...
# 2  埃里克问贝拉今天老板房间里发生了什么，老板是否生气。贝拉回答说老板并没有生气，反而对他们拒绝...
# 3  玛丽：嘿，我有点缺钱，能借我几百元吗？\n卡特：好的，给我一个小时，我在火车站。\n玛丽：行...
# 4  杰克提议后来喝鸡尾酒，梅激动地回应“是！”她表示自己确实很紧张。杰克猜测了，梅叹了口气，承认...
#
#                                 reference_summary_zh  \
# 0  佩顿给麦克斯提供了卖衣服的网站。他喜欢浏览、试穿衣服，但不一定都会买。他经常买衣服和书，因为...
# 1  凯利很害怕芬兰雕塑花园里的人物，因为她觉得那些人物的脸非常病态。对奥利来说，这就像日本的人偶...
# 2            贝拉和埃里克拒绝了一个客户的要求。他们老板很赞赏这个决定。他会吸引新的客户来。
# 3                             玛丽的钱用完了，卡特打算一小时后借给她一点。
# 4                                      杰克和梅一会儿要喝鸡尾酒。
#
#                                 reference_summary_en  \
# 0  Payton provides Max with websites selling clot...
# 1  Kelly is scared of sculpture garden figures in...
# 2  Bella and Eric dismissed a request of a client...
# 3  Mary ran out of money. Carter is going to lend...
# 4           Jack and May will drink cocktails later.
#
#                                             dialogue
# 0  Max: Know any good sites to buy clothes from?\...
# 1  Ollie: Okay, Kelly! Ur up nxt!\r\nKelly: Me? I...
# 2  Eric: Hey Bella, What happened today in boss's...
# 3  Mary: hey, im kinda broke, lend me a few box\r...
# 4  Jack: Cocktails later?\r\nMay: YES!!!\r\nMay: ...

# %%
df.groupby("model_name").size()
# Out:
# model_name
# aya-expanse:8b    100
# gemma4:e4b        100
# qwen3.5:9b        100
# dtype: int64

# %%
sample_index = 0
df[df["sample_index"] == sample_index][[
    "model_name",
    "generated_summary_zh",
    "reference_summary_zh",
    "reference_summary_en",
    "dialogue",
]]
# Out:
#          model_name                               generated_summary_zh  \
# 0    aya-expanse:8b  麦克斯问派顿是否知道哪里可以买到好衣服。派顿列出了几个网站，但表示通常会从两个或三个网站购买...
# 100      gemma4:e4b  两人讨论了购买衣服的网站，并分享了各自的购物习惯。Max询问Payton是否喜欢购物，Pay...
# 200      qwen3.5:9b  Max 询问购买衣物的网站，Payton 推荐了多个并解释自己通常只从其中两三个选购。随后两...
#
#                                   reference_summary_zh  \
# 0    佩顿给麦克斯提供了卖衣服的网站。他喜欢浏览、试穿衣服，但不一定都会买。他经常买衣服和书，因为...
# 100  佩顿给麦克斯提供了卖衣服的网站。他喜欢浏览、试穿衣服，但不一定都会买。他经常买衣服和书，因为...
# 200  佩顿给麦克斯提供了卖衣服的网站。他喜欢浏览、试穿衣服，但不一定都会买。他经常买衣服和书，因为...
#
#                                   reference_summary_en  \
# 0    Payton provides Max with websites selling clot...
# 100  Payton provides Max with websites selling clot...
# 200  Payton provides Max with websites selling clot...
#
#                                               dialogue
# 0    Max: Know any good sites to buy clothes from?\...
# 100  Max: Know any good sites to buy clothes from?\...
# 200  Max: Know any good sites to buy clothes from?\...
